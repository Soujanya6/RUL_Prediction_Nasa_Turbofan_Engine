# %% [markdown]
# **Data Description**
#
# Basically we have the data of Nasa aircraft's Turbofan Engine, their life time and performance in verious setting Cycles.
# as we all know a machine are not immortal for allwase like everything else so after a surtain time aircraft components are dilapidated and reducing their life day by day, which are affects directly their reliability and performance.
#
# **Problem Statement**
#
# In this project we will be provide a useful model to predict the Remaining Useful Life(RUL) based on the given life cycle data. what's we get the necessary maintenance behavior from the privious records of their durability and longevity so that model can figure out the remaining cycles which can be used for farther fly and can stop that anomaly which are cause of big trouble during flight.

# %% [markdown]
# *Pre Modeling Task*-
#
# >**Literature Review**
#
# This section briefly reviews the existing literature on the turbofan engine RUL estimation like
# 1. Traditional model-based techniques usually employ algorithms like Kalman filter (KF), extended Kalman filter (EKF) and particles filters to come up with mathematical formulation of machine based on multi sensor time series sequence data
# 2. presented machine learning based support
# vector regression (SVR) model to project the direct association between multivariate sensor data or health index and the aircraft turbofan engine RUL
# 3.  implemented the auto-regressive integrated moving average (ARIMA) model and support vector machine (SVR) methods collectively to estimate the RUL.
# The desired features can be created by analyzing prior learning about the degradation models.
#
# Across all these techniques for turbofan engine RUL prediction, Machine Learning and deep neural network-based methods have gained vast popularity.introduced a multi-objective evolutionary algorithm to expand and organized the deep belief network into multiple parallel networks simultaneously to accomplish the two convicting objectives i.e. diversity and accuracy.
#
# figuring out open source implementing if available

# %% [markdown]
# *defining the data-*
#
# >**what is Input X**
#
# as we can see in our data description we have diffrent setting to messuring our sensor data as feature what's will be used in building the model as Xlable, so at the beginning we start with settings ("setting1" : Operation Setting 1,"setting2" : Operation Setting 2,"setting3" : Operation Setting 3) and the sensor fatch data with ("sensor1" : Fan Inlet Temperature (◦R),"sensor2" : LPC Outlet Temperature (◦R),"sensor3" : HPC Outlet Temperature (◦R),"sensor4" : LPT Outlet Temperature (◦R),"sensor5" : Fan Inlet Pressure (psia),"sensor6" : Bypass-Duct Pressure (psia),"sensor7" : HPC Outlet Pressure (psia),"sensor8" : Physical Fan Speed (rpm),"sensor9" : Physical Core Speed (rpm),"sensor10" : Engine Pressure Ratio(P50/P2),"sensor11" : HPC Outlet Static Pressure (psia),"sensor12" : Ratio of Fuel Flow to Ps30 (pps/psia),"sensor13" : Corrected Fan Speed (rpm),"sensor14" : Corrected Core Speed (rpm),"sensor15" : Bypass Ratio,"sensor16" : Burner Fuel-Air Ratio,"sensor17" : Bleed Enthalpy,"sensor18" : Required Fan Speed,"sensor19" : Required Fan Conversion Speed,"sensor20" : High-Pressure Turbines Cool Air Flow,"sensor21" : Low-Pressure Turbines Cool Air Flow) these sensors.
#
# >***what is Output Y***
#
# It is besically the Remaining Useful Life(RUL) "cycle" : Time, In Cycles what's we wnat to predict accurately with our model.

# %% [markdown]
# ***Proof Of concept and Production Phase***
#
# as we find after reviewing such articles there was many times scientists are trying to build more and more accurate model using different methods and different machine learning algorithms and they got different accuracy.
#
# **chart shown here:-**
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ***Performance level we need-***
#
# Human-Level Performance (HLP) refers to a predictive model achieving results comparable to what a domain expert could produce through manual analysis, inspection. Predicting the degradation trend and end-of-life point as accurately as a skilled maintenance engineer, based on vibration, temperature, and operational readings, and Making predictions that are timely, interpretable, and actionable, not just statistically accurate.
#
# HLP(Huaman Level Performance) Rising Efficiency

# %% [markdown]
# Data PipeLine we used-
#
# Data drift and Concept drift defining to retrain for CI/CD

# %% [markdown]
# *Approaches to solve*-
#
# >**Data centric and Model centric**
#
# we have used diffrent algorithm to get the best accureacy where data is fixed, The C-MAPSS (Commercial Modular Aero-Propulsion System Simulation) dataset was developed by NASA to simulate the degradation of turbofan jet engines under various operational conditions and fault modes and used Linear Regression,Random Forest,SVR,XGBoost,type model to find better accurecy.
#
# Also we try to find the best outcome with fixed the model and feed diffrent section of randomly suffled data.
